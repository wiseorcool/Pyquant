# %%
import seaborn as sns
import pandas as pd

# %%
titanic= sns.load_dataset("titanic")

# %%
print(titanic.shape)
print(titanic.head(5))
print(titanic.info())
# Out:
# (891, 15)
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...

# %%
titanic.sex = titanic.sex.astype("category")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    category
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(3), float64(2), int64(4), object(4)
# memory usage: 74.7+ KB

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.age.fillna(titanic.age.median(),inplace=True)
# Out:
# /var/folders/c9/whb3jh8n0sz1zw9tjll5y44r0000gn/T/ipykernel_8832/2207343802.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic.age.fillna(titanic.age.median(),inplace=True)

# %%
titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.dropna(subset=["embarked"],inplace=True)

# %%
titanic.shape
# Out:
# (889, 15)

# %%
print(len(titanic[titanic.age>60]))
titanic[titanic.age>60]
# Out:
# 21
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 33          0       2    male  66.0      0      0   10.5000        S  Second
# 54          0       1    male  65.0      0      1   61.9792        C   First
# 96          0       1    male  71.0      0      0   34.6542        C   First
# 116         0       3    male  70.5      0      0    7.7500        Q   Third
# 170         0       1    male  61.0      0      0   33.5000        S   First
# 252         0       1    male  62.0      0      0   26.5500        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 280         0       3    male  65.0      0      0    7.7500        Q   Third
# 326         0       3    male  61.0      0      0    6.2375        S   Third
# 438         0       1    male  64.0      1      4  263.0000        S   First
# 456         0       1    male  65.0      0      0   26.5500        S   First
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    category
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  deck         201 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        889 non-null    object
#  14  alone        889 non-null    bool
# dtypes: bool(2), category(3), float64(2), int64(4), object(4)
# memory usage: 81.3+ KB

# %%
children_survived = titanic[(titanic.age<10) & (titanic.survived==1)& (titanic.alive=="yes")]
print(len(children_survived))
print(children_survived)
# Out:
# 38
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 10          1       3  female  4.00      1      1   16.7000        S   Third
# 43          1       2  female  3.00      1      2   41.5792        C  Second
# 58          1       2  female  5.00      1      2   27.7500        S  Second
# 78          1       2    male  0.83      0      2   29.0000        S  Second
# 165         1       3    male  9.00      0      2   20.5250        S   Third
# 172         1       3  female  1.00      1      1   11.1333        S   Third
# 183         1       2    male  1.00      2      1   39.0000        S  Second
# 184         1       3  female  4.00      0      2   22.0250        S   Third
# 193         1       2    male  3.00      1      1   26.0000        S  Second
# 233         1       3  female  5.00      4      2   31.3875        S   Third
# 237         1       2  female  8.00      0      2   26.2500        S  Second
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    category
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  deck         201 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        889 non-null    object
#  14  alone        889 non-null    bool
# dtypes: bool(2), category(3), float64(2), int64(4), object(4)
# memory usage: 81.3+ KB

# %%
titanic["is_child"]=titanic["age"]<10

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    category
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  deck         201 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        889 non-null    object
#  14  alone        889 non-null    bool
#  15  is_child     889 non-null    bool
# dtypes: bool(3), category(3), float64(2), int64(4), object(4)
# memory usage: 82.2+ KB

# %%
titanic.head(2)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone  is_child
# 0    man        True  NaN  Southampton    no  False     False
# 1  woman       False    C    Cherbourg   yes  False     False

# %%
titanic["family_size"]= titanic["sibsp"] + titanic["parch"] + 1

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    category
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  deck         201 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        889 non-null    object
#  14  alone        889 non-null    bool
#  15  is_child     889 non-null    bool
#  16  family_size  889 non-null    int64
# dtypes: bool(3), category(3), float64(2), int64(5), object(4)
# ...

# %%
titanic.head(5)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  is_child  family_size
# 0    man        True  NaN  Southampton    no  False     False            2
# 1  woman       False    C    Cherbourg   yes  False     False            2
# 2  woman       False  NaN  Southampton   yes   True     False            1
# 3  woman       False    C  Southampton   yes  False     False            2
# 4    man        True  NaN  Southampton    no   True     False            1

# %%
titanic.groupby("sex")["survived"].mean()
# Out:
# /var/folders/c9/whb3jh8n0sz1zw9tjll5y44r0000gn/T/ipykernel_8832/3356119000.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby("sex")["survived"].mean()
# sex
# female    0.740385
# male      0.188908
# Name: survived, dtype: float64

# %%
titanic.groupby("class")["fare"].mean()
# Out:
# /var/folders/c9/whb3jh8n0sz1zw9tjll5y44r0000gn/T/ipykernel_8832/3754171250.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic.groupby("class")["fare"].mean()
# class
# First     84.193516
# Second    20.662183
# Third     13.675550
# Name: fare, dtype: float64

# %%
pd.crosstab(titanic["sex"], titanic["class"], values=titanic["survived"], aggfunc="mean")
# Out:
# class      First    Second     Third
# sex
# female  0.967391  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
pd.crosstab(titanic['sex'],titanic['class'],aggfunc='mean',values=titanic['survived'])
# Out:
# class      First    Second     Third
# sex
# female  0.967391  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.pivot_table(values="survived", index="sex", columns="class", aggfunc="mean")
# Out:
# /var/folders/c9/whb3jh8n0sz1zw9tjll5y44r0000gn/T/ipykernel_8832/1630561.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   titanic.pivot_table(values="survived", index="sex", columns="class", aggfunc="mean")
# class      First    Second     Third
# sex
# female  0.967391  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
titanic.shape
# Out:
# (889, 17)

# %%
titanic=titanic.sort_values("fare",ascending=True)

# %%
titanic.shape
# Out:
# (889, 17)

# %%
titanic.head(10)
# Out:
#      survived  pclass   sex   age  sibsp  parch  fare embarked   class  who  \
# 271         1       3  male  25.0      0      0   0.0        S   Third  man
# 597         0       3  male  49.0      0      0   0.0        S   Third  man
# 302         0       3  male  19.0      0      0   0.0        S   Third  man
# 633         0       1  male  28.0      0      0   0.0        S   First  man
# 277         0       2  male  28.0      0      0   0.0        S  Second  man
# 413         0       2  male  28.0      0      0   0.0        S  Second  man
# 674         0       2  male  28.0      0      0   0.0        S  Second  man
# 263         0       1  male  40.0      0      0   0.0        S   First  man
# 466         0       2  male  28.0      0      0   0.0        S  Second  man
# 732         0       2  male  28.0      0      0   0.0        S  Second  man
#
#      adult_male deck  embark_town alive  alone  is_child  family_size
# ...

# %%
titanic.sort_index(axis=0, ascending=True,inplace=True)

# %%
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male  28.0      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone  is_child  family_size
# 0    man        True  NaN  Southampton    no  False     False            2
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 889 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     889 non-null    int64
#  1   pclass       889 non-null    int64
#  2   sex          889 non-null    category
#  3   age          889 non-null    float64
#  4   sibsp        889 non-null    int64
#  5   parch        889 non-null    int64
#  6   fare         889 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        889 non-null    category
#  9   who          889 non-null    object
#  10  adult_male   889 non-null    bool
#  11  deck         201 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        889 non-null    object
#  14  alone        889 non-null    bool
#  15  is_child     889 non-null    bool
#  16  family_size  889 non-null    int64
# dtypes: bool(3), category(3), float64(2), int64(5), object(4)
# ...

# %%
import matplotlib.pyplot as plt

titanic['age'].hist(bins=30)
plt.title("Age Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
titanic.age.hist(bins=15)
plt.title("Age Distribution with less Distributions")
plt.xlabel("Age")
plt.ylabel("Number of Passengers")
plt.show()

# %%
sns.barplot(data=titanic, x='class',y='survived',hue='sex')
plt.show()

# %%
survival_rate = pd.DataFrame()
survival_rate['total'] = titanic.who.value_counts()
survival_rate['survived'] = titanic[titanic.alive=='yes'].who.value_counts()
survival_rate
# Out:
#        total  survived
# who
# man      537        88
# woman    269       203
# child     83        49

# %%
survival_rate['survival_rate'] = survival_rate['survived'] / survival_rate['total']

# %%
survival_rate
# Out:
#        total  survived  survival_rate
# who
# man      537        88       0.163873
# woman    269       203       0.754647
# child     83        49       0.590361

# %%
sns.barplot(x="who", y="survival_rate", data=survival_rate)
plt.title("Survival Rate by Who")
plt.xlabel("Who")
plt.ylabel("Survival Rate")
plt.show()
