# %% [markdown]
# # 🐼 Pandas Challenge Notebook
#
# This notebook contains **practice questions** to help you strengthen your Pandas skills.
# Try solving each one without looking at the solutions first!
#
# 👉 Dataset suggestion: Titanic dataset
# ```python
# import pandas as pd
# df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# df.head()
# ```

# %%
import pandas as pd
import seaborn as sns
titanic_df = sns.load_dataset('titanic')

# %% [markdown]
# ## 1. Data Exploration

# %% [markdown]
# **Q1. Show the first 7 rows of the dataframe.**

# %%
# Your code here
titanic_df.head(7)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
# 5         0       3    male   NaN      0      0   8.4583        Q  Third
# 6         0       1    male  54.0      0      0  51.8625        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# ...

# %% [markdown]
# **Q2. How many rows and columns does the dataset have?**

# %%
# Your code here
titanic_df.shape
# Out:
# (891, 15)

# %% [markdown]
# **Q3. Which columns have missing values and how many?**

# %%
# Your code here
# titanic_df.info()
titanic_df.isna().sum().sort_values(ascending=False)
# Out:
# deck           688
# age            177
# embarked         2
# embark_town      2
# survived         0
# pclass           0
# sex              0
# sibsp            0
# parch            0
# fare             0
# class            0
# who              0
# adult_male       0
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ## 2. Selecting & Creating Columns

# %% [markdown]
# **Q1. Select only the `Name` and `Fare` columns.**

# %%
# Your code here
titanic_df[['age','fare']].head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %% [markdown]
# **Q2. Create a new column `FamilySize = SibSp + Parch + 1`.**

# %%
titanic_df['sibsp']
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: sibsp, Length: 891, dtype: int64

# %%
titanic_df['FamilySize'] = titanic_df['sibsp'] + titanic_df['parch'] + 1

# %%
# Your code here
titanic_df['FamilySize']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: FamilySize, Length: 891, dtype: int64

# %% [markdown]
# **Q3. Rename column `Pclass` to `Class`.**

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  FamilySize   891 non-null    int64
# dtypes: bool(2), category(2), float64(2), int64(5), object(5)
# memory usage: 87.6+ KB

# %%
# Your code here
titanic_df.rename(columns={'pclass':'class'}, errors='raise',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/c9/whb3jh8n0sz1zw9tjll5y44r0000gn/T/ipykernel_4728/2859771732.py in ?()
#       1 # Your code here
# ----> 2 titanic_df.rename(columns={'pclass':'class'}, errors='raise',inplace=True)
#
# ~/anaconda3/envs/my_quant_lab/lib/python3.11/site-packages/pandas/core/frame.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5770         0  1  4
#    5771         2  2  5
#    5772         4  3  6
#    5773         """
# -> 5774         return super()._rename(
#    5775             mapper=mapper,
#    5776             index=index,
#    5777             columns=columns,
#
# ~/anaconda3/envs/my_quant_lab/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1126                         label
# ...

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   class        891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
#  15  FamilySize   891 non-null    int64
# dtypes: bool(2), category(2), float64(2), int64(5), object(5)
# memory usage: 87.6+ KB

# %% [markdown]
# ## 3. Filtering Rows

# %% [markdown]
# **Q1. Find all passengers older than **60 years**.**

# %%
# Your code here

titanic_df[titanic_df['age']>60][['age','alive']].sort_values('age',ascending=False)
# Out:
#       age alive
# 630  80.0   yes
# 851  74.0    no
# 493  71.0    no
# 96   71.0    no
# 116  70.5    no
# 745  70.0    no
# 672  70.0    no
# 33   66.0    no
# 456  65.0    no
# 54   65.0    no
# 280  65.0    no
# 438  64.0    no
# 545  64.0    no
# 275  63.0   yes
# 483  63.0   yes
# 555  62.0    no
# 570  62.0   yes
# 252  62.0    no
# 829  62.0   yes
# 326  61.0    no
# 625  61.0    no
# 170  61.0    no

# %% [markdown]
# **Q2. Get passengers who paid a fare **greater than 100**.**

# %%
# Your code here
titanic_df[titanic_df['fare']>100][['age','fare']]
# Out:
#        age      fare
# 27   19.00  263.0000
# 31     NaN  146.5208
# 88   23.00  263.0000
# 118  24.00  247.5208
# 195  58.00  146.5208
# 215  31.00  113.2750
# 258  35.00  512.3292
# 268  58.00  153.4625
# 269  35.00  135.6333
# 297   2.00  151.5500
# 299  50.00  247.5208
# 305   0.92  151.5500
# 306    NaN  110.8833
# 307  17.00  108.9000
# 311  18.00  262.3750
# 318  31.00  164.8667
# 319  40.00  134.5000
# 325  36.00  135.6333
# 332  38.00  153.4625
# 334    NaN  133.6500
# 337  41.00  134.5000
# 341  24.00  263.0000
# 373  22.00  135.6333
# 377  27.00  211.5000
# 380  42.00  227.5250
# 390  36.00  120.0000
# 393  23.00  113.2750
# 435  14.00  120.0000
# 438  64.00  263.0000
# 498  25.00  151.5500
# 505  18.00  108.9000
# 527    NaN  221.7792
# 537  30.00  106.4250
# 544  50.00  106.4250
# 550  17.00  110.8833
# 557    NaN  227.5250
# 581  39.00  110.8833
# 609  40.00  153.4625
# 659  58.00  113.2750
# 660  50.00  133.6500
# 679  36.00  512.3292
# 689  15.00  211.3375
# ...

# %% [markdown]
# **Q3. Show all **female passengers in 1st class**.**

# %%
# Your code here

# %% [markdown]
# ## 4. GroupBy & Aggregation

# %% [markdown]
# **Q1. What is the average age in each passenger class?**

# %%
# Your code here

# %% [markdown]
# **Q2. Count how many survived vs did not survive, grouped by gender.**

# %%
# Your code here

# %% [markdown]
# **Q3. What was the highest fare paid in each class?**

# %%
# Your code here

# %% [markdown]
# ## 5. Sorting & Ranking

# %% [markdown]
# **Q1. Get the top **5 youngest passengers**.**

# %%
# Your code here

# %% [markdown]
# **Q2. Get the top **5 passengers who paid the most fare**.**

# %%
# Your code here

# %% [markdown]
# ## 6. Apply & Functions

# %% [markdown]
# **Q1. Create a column `AgeGroup` that says `'Child'` if Age < 18 else `'Adult'`.**

# %%
# Your code here

# %% [markdown]
# **Q2. Create a column that shows whether the passenger’s name starts with 'A'.**

# %%
# Your code here

# %% [markdown]
# ## 7. Advanced (Pivot, Merge, Resample)

# %% [markdown]
# **Q1. Create a **pivot table** showing average fare by `Sex` and `Class`.**

# %%
# Your code here

# %% [markdown]
# **Q2. Make a tiny dataframe of 5 passenger IDs with notes, and merge it with the Titanic dataset.**

# %%
# Your code here

# %% [markdown]
# **Q3. (If your dataset has a `Date` column) Convert it to datetime and count passengers per month.**

# %%
# Your code here

# %% [markdown]
# ## 8. Visualization (optional)

# %% [markdown]
# **Q1. Plot a histogram of ages.**

# %%
# Your code here

# %% [markdown]
# **Q2. Make a bar chart of survival rate by passenger class.**

# %%
# Your code here
