# %%
import pandas as pd

# %%
data_df = pd.read_csv("symbols_valid_meta.csv")

# %%
data_df.head(5)
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# ...

# %%
data_df["Symbol"].dtype
# Out:
# dtype('O')

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nasdaq Traded     8049 non-null   object
#  1   Symbol            8049 non-null   object
#  2   Security Name     8049 non-null   object
#  3   Listing Exchange  8049 non-null   object
#  4   Market Category   8049 non-null   object
#  5   ETF               8049 non-null   object
#  6   Round Lot Size    8049 non-null   float64
#  7   Test Issue        8049 non-null   object
#  8   Financial Status  3383 non-null   object
#  9   CQS Symbol        4666 non-null   object
#  10  NASDAQ Symbol     8049 non-null   object
#  11  NextShares        8049 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 754.7+ KB

# %%
print(data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nasdaq Traded     8049 non-null   object
#  1   Symbol            8049 non-null   object
#  2   Security Name     8049 non-null   object
#  3   Listing Exchange  8049 non-null   object
#  4   Market Category   8049 non-null   object
#  5   ETF               8049 non-null   object
#  6   Round Lot Size    8049 non-null   float64
#  7   Test Issue        8049 non-null   object
#  8   Financial Status  3383 non-null   object
#  9   CQS Symbol        4666 non-null   object
#  10  NASDAQ Symbol     8049 non-null   object
#  11  NextShares        8049 non-null   object
# dtypes: float64(1), object(11)
# memory usage: 754.7+ KB
# None

# %%
data_df.head(5)
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# ...

# %%
data_df["Symbol"] = data_df["Symbol"].astype("string")

# %%
data_df["Symbol"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 8049 entries, 0 to 8048
# Series name: Symbol
# Non-Null Count  Dtype
# --------------  -----
# 8049 non-null   string
# dtypes: string(1)
# memory usage: 63.0 KB

# %%
data_df["Symbol"].nunique()
# Out:
# 8049

# %%
data_df.shape
# Out:
# (8049, 12)

# %%
len(data_df)
# Out:
# 8049

# %%
data_df["Symbol"] = data_df["Symbol"].astype("string")

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nasdaq Traded     8049 non-null   object
#  1   Symbol            8049 non-null   string
#  2   Security Name     8049 non-null   object
#  3   Listing Exchange  8049 non-null   object
#  4   Market Category   8049 non-null   object
#  5   ETF               8049 non-null   object
#  6   Round Lot Size    8049 non-null   float64
#  7   Test Issue        8049 non-null   object
#  8   Financial Status  3383 non-null   object
#  9   CQS Symbol        4666 non-null   object
#  10  NASDAQ Symbol     8049 non-null   object
#  11  NextShares        8049 non-null   object
# dtypes: float64(1), object(10), string(1)
# memory usage: 754.7+ KB

# %%
data_df.head(5)
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# ...

# %%
data_df.groupby("Listing Exchange")["Symbol"].nunique()
# Out:
# Listing Exchange
# A     253
# N    2520
# P    1542
# Q    3383
# Z     351
# Name: Symbol, dtype: int64

# %%
data_df.groupby("Listing Exchange")["Symbol"].count()
# Out:
# Listing Exchange
# A     253
# N    2520
# P    1542
# Q    3383
# Z     351
# Name: Symbol, dtype: int64

# %%
unique_exchanges = data_df["Listing Exchange"].unique()

# %%
unique_exchanges.sort()

# %%
unique_exchanges
# Out:
# array(['A', 'N', 'P', 'Q', 'Z'], dtype=object)

# %%
data_df.head(5)
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# ...

# %%
data_df.groupby("Nasdaq Traded").count()
# Out:
#                Symbol  Security Name  Listing Exchange  Market Category   ETF  \
# Nasdaq Traded
# Y                8049           8049              8049             8049  8049
#
#                Round Lot Size  Test Issue  Financial Status  CQS Symbol  \
# Nasdaq Traded
# Y                        8049        8049              3383        4666
#
#                NASDAQ Symbol  NextShares
# Nasdaq Traded
# Y                       8049        8049

# %%
data_df["Nasdaq Traded"].value_counts()
# Out:
# Nasdaq Traded
# Y    8049
# Name: count, dtype: int64

# %%
data_df["Nasdaq Traded"].unique()
# Out:
# array(['Y'], dtype=object)

# %%
	
data_df["Listing Exchange"].unique()
# Out:
# array(['N', 'P', 'Q', 'A', 'Z'], dtype=object)

# %%
data_df["Listing Exchange"].nunique()
# Out:
# 5

# %%
data_df.info()
data_df.shape
data_df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nasdaq Traded     8049 non-null   object
#  1   Symbol            8049 non-null   string
#  2   Security Name     8049 non-null   object
#  3   Listing Exchange  8049 non-null   object
#  4   Market Category   8049 non-null   object
#  5   ETF               8049 non-null   object
#  6   Round Lot Size    8049 non-null   float64
#  7   Test Issue        8049 non-null   object
#  8   Financial Status  3383 non-null   object
#  9   CQS Symbol        4666 non-null   object
#  10  NASDAQ Symbol     8049 non-null   object
#  11  NextShares        8049 non-null   object
# dtypes: float64(1), object(10), string(1)
# memory usage: 754.7+ KB
# Nasdaq Traded               object
# Symbol              string[python]
# Security Name               object
# ...

# %%
data_df.dtypes
# Out:
# Nasdaq Traded               object
# Symbol              string[python]
# Security Name               object
# Listing Exchange            object
# Market Category             object
# ETF                         object
# Round Lot Size             float64
# Test Issue                  object
# Financial Status            object
# CQS Symbol                  object
# NASDAQ Symbol               object
# NextShares                  object
# dtype: object

# %%
data_df.describe()
# Out:
#        Round Lot Size
# count     8049.000000
# mean        99.942974
# std          2.289194
# min          1.000000
# 25%        100.000000
# 50%        100.000000
# 75%        100.000000
# max        100.000000

# %%
data_df["Nasdaq Traded"] = data_df["Nasdaq Traded"].astype("category")

# %%
data_df.dtypes
# Out:
# Nasdaq Traded             category
# Symbol              string[python]
# Security Name               object
# Listing Exchange            object
# Market Category             object
# ETF                         object
# Round Lot Size             float64
# Test Issue                  object
# Financial Status            object
# CQS Symbol                  object
# NASDAQ Symbol               object
# NextShares                  object
# dtype: object

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nasdaq Traded     8049 non-null   category
#  1   Symbol            8049 non-null   string
#  2   Security Name     8049 non-null   object
#  3   Listing Exchange  8049 non-null   object
#  4   Market Category   8049 non-null   object
#  5   ETF               8049 non-null   object
#  6   Round Lot Size    8049 non-null   float64
#  7   Test Issue        8049 non-null   object
#  8   Financial Status  3383 non-null   object
#  9   CQS Symbol        4666 non-null   object
#  10  NASDAQ Symbol     8049 non-null   object
#  11  NextShares        8049 non-null   object
# dtypes: category(1), float64(1), object(9), string(1)
# memory usage: 699.8+ KB

# %%
data_df.describe()
# Out:
#        Round Lot Size
# count     8049.000000
# mean        99.942974
# std          2.289194
# min          1.000000
# 25%        100.000000
# 50%        100.000000
# 75%        100.000000
# max        100.000000

# %%
data_df.dtypes
# Out:
# Nasdaq Traded             category
# Symbol              string[python]
# Security Name               object
# Listing Exchange            object
# Market Category             object
# ETF                         object
# Round Lot Size             float64
# Test Issue                  object
# Financial Status            object
# CQS Symbol                  object
# NASDAQ Symbol               object
# NextShares                  object
# dtype: object

# %%
data_df.head()
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# ...

# %%
data_df["Listing Exchange"].unique()
# Out:
# array(['N', 'P', 'Q', 'A', 'Z'], dtype=object)

# %%
data_df["Listing Exchange"].nunique()
# Out:
# 5

# %%
data_df.groupby("Listing Exchange").count()
# Out:
#                   Nasdaq Traded  Symbol  Security Name  Market Category   ETF  \
# Listing Exchange
# A                           253     253            253              253   253
# N                          2520    2520           2520             2520  2520
# P                          1542    1542           1542             1542  1542
# Q                          3383    3383           3383             3383  3383
# Z                           351     351            351              351   351
#
#                   Round Lot Size  Test Issue  Financial Status  CQS Symbol  \
# Listing Exchange
# A                            253         253                 0         253
# N                           2520        2520                 0        2520
# P                           1542        1542                 0        1542
# Q                           3383        3383              3383           0
# Z                            351         351                 0         351
#
# ...

# %%
data_df["Market Category"].unique()
# Out:
# array([' ', 'G', 'Q', 'S'], dtype=object)

# %%
data_df["Market Category"].nunique()
# Out:
# 4

# %%
data_df.groupby("Market Category").count()
# Out:
#                  Nasdaq Traded  Symbol  Security Name  Listing Exchange   ETF  \
# Market Category
#                           4666    4666           4666              4666  4666
# G                          900     900            900               900   900
# Q                         1531    1531           1531              1531  1531
# S                          952     952            952               952   952
#
#                  Round Lot Size  Test Issue  Financial Status  CQS Symbol  \
# Market Category
#                            4666        4666                 0        4666
# G                           900         900               900           0
# Q                          1531        1531              1531           0
# S                           952         952               952           0
#
#                  NASDAQ Symbol  NextShares
# Market Category
#                           4666        4666
# G                          900         900
# ...

# %%
data_df.head(5)
# Out:
#   Nasdaq Traded Symbol                                      Security Name  \
# 0             Y      A            Agilent Technologies, Inc. Common Stock
# 1             Y     AA                    Alcoa Corporation Common Stock
# 2             Y   AAAU                       Perth Mint Physical Gold ETF
# 3             Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4             Y   AADR                AdvisorShares Dorsey Wright ADR ETF
#
#   Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 0                N                   N           100.0          N
# 1                N                   N           100.0          N
# 2                P                   Y           100.0          N
# 3                Q               G   N           100.0          N
# 4                P                   Y           100.0          N
#
#   Financial Status CQS Symbol NASDAQ Symbol NextShares
# 0              NaN          A             A          N
# ...

# %%
len(data_df[data_df["Round Lot Size"]<100])
# Out:
# 5

# %%
data_df[data_df["Round Lot Size"]<100]
# Out:
#      Nasdaq Traded Symbol                               Security Name  \
# 743              Y     BH  Biglari Holdings Inc. Class B Common Stock
# 1806             Y    DIT     AMCON Distributing Company Common Stock
# 4662             Y    MKL             Markel Corporation Common Stock
# 5169             Y    NVR                      NVR, Inc. Common Stock
# 6406             Y    SEB           Seaboard Corporation Common Stock
#
#      Listing Exchange Market Category ETF  Round Lot Size Test Issue  \
# 743                 N                   N            10.0          N
# 1806                A                   N            10.0          N
# 4662                N                   N            10.0          N
# 5169                N                   N            10.0          N
# 6406                A                   N             1.0          N
#
#      Financial Status CQS Symbol NASDAQ Symbol NextShares
# 743               NaN         BH            BH          N
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8049 entries, 0 to 8048
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Nasdaq Traded     8049 non-null   category
#  1   Symbol            8049 non-null   string
#  2   Security Name     8049 non-null   object
#  3   Listing Exchange  8049 non-null   object
#  4   Market Category   8049 non-null   object
#  5   ETF               8049 non-null   object
#  6   Round Lot Size    8049 non-null   float64
#  7   Test Issue        8049 non-null   object
#  8   Financial Status  3383 non-null   object
#  9   CQS Symbol        4666 non-null   object
#  10  NASDAQ Symbol     8049 non-null   object
#  11  NextShares        8049 non-null   object
# dtypes: category(1), float64(1), object(9), string(1)
# memory usage: 699.8+ KB
